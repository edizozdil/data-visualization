# %%
import pandas as pd

# %%
import os

# %%
os.chdir("C:\Users\EdizOzdil\Downloads")
# Out:
#   File "C:\Users\EdizOzdil\AppData\Local\Temp\ipykernel_14556\2062004320.py", line 1
#     os.chdir("C:\Users\EdizOzdil\Downloads")
#                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
index=pd.read_csv("TechnologyIndex.csv",index_col="Country")

# %%
index
# Out:
#                       Rank      iPhone     Android      MacBook  \
# Country
# Kuwait                   1     $641.50     $539.18      $795.38
# Saudi Arabia             2     $513.86     $699.61    $1,054.98
# Malaysia                 3     $532.06     $631.66    $1,010.31
# Canada                   4     $555.25     $625.04    $1,118.10
# United Arab Emirates     5     $498.25     $592.31    $1,073.30
# ...                    ...         ...         ...          ...
# Guatemala               68     $889.56     $591.31    $1,525.26
# Brazil                  69     $843.30     $948.74    $3,390.96
# Brunei                  70     $764.02     $856.47    $2,326.47
# Angola                  71     $401.94   $2,641.01    $1,001.06
# Venezuela               72  $97,813.82  $78,054.19  $176,005.34
#
#                      Windows Powered         PS4    Xbox one   iPad mini  \
# Country
# Kuwait                       $528.34     $315.83     $418.50     $242.90
# ...
