# %%
from unittest import result
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import numpy as np

##tarticle içindeki tek h1

# website = 'https://subslikescript.com/movie/Titanic-120338'
# result = requests.get(website)
# content = result.text
# soup = BeautifulSoup(content, 'html.parser')
# #print(soup.prettify())
# box = soup.find('article', class_= "main-article")
# title = box.find('h1').get_text()
# print(title)

##entry divindeki partial_entry clasına sahip olan p'yi yazdırmak.

# website = 'https://www.tripadvisor.com/Restaurant_Review-g293974-d806407-Reviews-Haci_Abdullah_Lokantasi-Istanbul.html'
# headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# result = requests.get(url = website, headers=headers)
# content = result.text
# soup = BeautifulSoup(content, 'html.parser')
# # # # #print(soup.prettify())
# box = soup.find('div', class_ = "entry")
# comment = box.find('p', class_ ="partial_entry").get_text()
# print(comment)

##entry classındaki TÜM divlerin içindeki partial classındaki p'ler.

# website = 'https://www.tripadvisor.com/Restaurant_Review-g293974-d806407-Reviews-Haci_Abdullah_Lokantasi-Istanbul.html'
# headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# result = requests.get(url = website, headers=headers)
# content = result.text
# soup = BeautifulSoup(content, 'html.parser')
# divs = soup.findAll('div',{'class':'entry'})
# comments = []

# for p in divs:
#    comment = p.find('p',{'class':"partial_entry"})
#    comment = comment.text[0:]
#    #comment = comment.replace(',','')
#    comments.append(comment)
# print(comments)

##REWIEV CLASSINDAKI DIV - > ICINDEKI TUM partiel entry classındaki p nin içindeki tüm texxtler. bunbu SCV kutuphanesi ile csv dondurme.
# website = 'https://www.tripadvisor.com/Restaurant_Review-g293974-d806407-Reviews-Haci_Abdullah_Lokantasi-Istanbul.html'
# headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# result = requests.get(url = website, headers=headers)
# content = result.text
# soup = BeautifulSoup(content, 'html.parser')
# #divs = soup.find('div',{'class':'entry'})
# divs = soup.find('div',attrs = {'id':'REVIEWS'})
# comments = []

# for row in divs.findAll('p',{'class':"partial_entry"}):
#    comment = {}
#    comment['yorumlar'] = row.text
#    comments.append(comment)
#    print(comment)


# filename = 'deneme_comments6.csv'
# with open(filename, 'w', newline='') as f:
#      w = csv.DictWriter(f,['yorumlar'])
#      w.writeheader()
#      for comment in comments:
#          w.writerow(comment)


## Tek Satır Row
# website = 'https://www.tripadvisor.com/Restaurant_Review-g293974-d806407-Reviews-Haci_Abdullah_Lokantasi-Istanbul.html'
# headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# result = requests.get(url = website, headers=headers)
# content = result.text
# soup = BeautifulSoup(content, 'html.parser')
# #divs = soup.find('div',{'class':'entry'})
# divs = soup.find('div',attrs = {'id':'REVIEWS'})
# comments = []

# for row in divs.findAll('p',{'class':"partial_entry"}):
#    comment = {}
#    comment['yorumlar'] = row.text
#    comments.append(comment)

# filename = 'deneme_comments3.csv'
# with open(filename, 'w', newline='') as f:
#     w = csv.DictWriter(f,['yorumlar'])
#     w.writeheader()
#     for comment in comments:
#         w.writerow(comment)

# website = 'https://www.tripadvisor.com/Restaurant_Review-g293974-d806407-Reviews-Haci_Abdullah_Lokantasi-Istanbul.html'
# headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# result = requests.get(url = website, headers=headers)
# content = result.text
# soup = BeautifulSoup(content, 'html.parser')
# #divs = soup.find('div',{'class':'entry'})
# divs = soup.find('div',attrs = {'id':'REVIEWS'})
# comments = []

# for row in divs.findAll('p',{'class':"partial_entry"}):
#    comment = {}
#    comment['yorumlar'] = row.text
#    comments.append(comment)
#   # print(comment)
# a = pd.Series(comments)
# print(a)


website = 'https://www.tripadvisor.com/Restaurant_Review-g293974-d806407-Reviews-Haci_Abdullah_Lokantasi-Istanbul.html'
headers = {'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' 
            'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
result = requests.get(url = website, headers=headers)
content = result.text
soup = BeautifulSoup(content, 'html.parser')
#divs = soup.find('div',{'class':'entry'})
divs = soup.find('div',attrs = {'id':'REVIEWS'})
comments = []

for row in divs.findAll('p',{'class':"partial_entry"}):
   comment = {}
   comment['yorumlar'] = row.text
   comments.append(comment)
  # print(comment)

df = pd.DataFrame({'Yorumlar' : comments})
df.to_csv('yorumlar.csv', index=False,encoding='
# Out:
#   File "C:\Users\EdizOzdil\AppData\Local\Temp\ipykernel_19100\2612054251.py", line 131
#     df.to_csv('yorumlar.csv', index=False,encoding='
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL = "https://www.geeksforgeeks.org/data-structures/"
URL = "http://www.values.com/inspirational-quotes"
headers = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
r = requests.get(url=URL, headers=headers)
print(r.content)
soup = BeautifulSoup(r.content, 'html5lib')  # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
quotes = []  # a list to store quotes

table = soup.find('div', attrs={'id': 'all_quotes'})

for row in table.findAll('div',
                         attrs={'class': 'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)

filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f, ['theme', 'url', 'img', 'lines', 'author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)
# Out:
# b'<!DOCTYPE html>\n<html class="no-js" dir="ltr" lang="en-US">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width,initial-scale=1.0" />\n  <title>Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life</title>\n<meta name="description" content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors.">\n<meta name="keywords" content="pass, it, on, passiton, values, kindness">\n<meta name="twitter:site_name" content="The Foundation for a Better Life">\n<meta name="twitter:site" content="@passiton_values">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:description" content="Thank you for visiting.">\n<meta name="twitter:image" content="https://www.passiton.com/passiton_fbl.jpg">\n<meta property="og:url" content="https://www.passiton.com/inspirational-quotes">\n<meta property="og:site_name" content="The Foundation for a Better Life">\n<meta property="og:title" content="Welcome to PassItOn.com">\n<meta property="og:image" content="https://www.passiton.com/passiton_fbl.jpg">\n<meta property="og:description" content="Thank you for visiting.">\n<meta property="og:type" content="website">\n  <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\n  <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\n  <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\n  <link rel="manifest" href="/site.webmanifest">\n  <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#c8102e">\n  <meta name="msapplication-TileColor" content="#ffffff">\n  <meta name="theme-color" content="#ffffff">\n  <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" crossorigin="anonymous">\n  <link rel="stylesheet" href="/assets/application-e8e20e255c69ae39d804fef20f59772f15fb1bc96bf62568750ac089c781848a.css" data-turbo-track="reload" />\n  <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="vg7j9WsY_9UUg0Zi2FkQUpkGUs866XBTNO7KMMggMe2OdHue7US3lnEy-qwuqw2MGls1toYj9A3w0YhYitWVcg" />\n  \n  <!-- Global site tag (gtag.js) - Google Analytics -->\n  <script async src="https://www.googletagmanager.com/gtag/js?id=UA-1179606-29"></script>\n  <script>\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n    gtag(\'js\', new Date());\n    gtag(\'config\', \'UA-1179606-29\');\n  </script>\n\n  <script>\n    window.fbAsyncInit = function() {\n      FB.init({\n        appId            : \'483774921971842\',\n        autoLogAppEvents : true,\n        xfbml            : true,\n        version          : \'v6.0\'\n      });\n    };\n  </script>\n  <script async defer src="https://connect.facebook.net/en_US/sdk.js"></script>\n  <meta property="fb:app_id" content="483774921971842" />\n  <link rel="alternate" type="application/rss+xml" title="RSS" href="https://www.passiton.com/inspirational-quotes.atom" />\n\n</head>\n<body class=\'no-transition quotes_index\'>\n          <header>\n          <nav class="navbar navbar-default bootsnav background-transparent header-dark white-link navbar-fixed-top navbar-expand-lg nav-box-width">\n            <div class="container-fluid nav-header-container">\n\n              <div class="col-auto pl-0">\n                <a class="logo" title="Pass It On\xc2\xae" href="/"><img data-rjs="/assets/site/logo@2x-9d23e0957dd55796d7703439c50bc254ab2499f99c40f36603e12ede1b4171f0.png" class="logo-dark" alt="Pass It On" src="/assets/site/logo-1be5a8827b761a60c300142c5126fc96abc085520555801120a17feb4fa49495.png" /><img data-rjs="/assets/site/logo-white@2x-52919a88e1cc19ef3bf0977d9618e8428645f46fac094c1925aa0898381647f3.png" class="logo- ...
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="pass, it, on, passiton, values, kindness" name="keywords"/>
#   <meta content="The Foundation for a Better Life" name="twitter:site_name"/>
#   <meta content="@passiton_values" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Thank you for visiting." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" name="twitter:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" property="og:url"/>
#   <meta content="The Foundation for a Better Life" property="og:site_name"/>
#   <meta content="Welcome to PassItOn.com" property="og:title"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" property="og:image"/>
#   <meta content="Thank you for visiting." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/application-e8e20e255c69ae39d804fef20f59772f15fb1bc96bf62568750ac089c781848a.css" rel="stylesheet"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="vg7j9WsY_9UUg0Zi2FkQUpkGUs866XBTNO7KMMggMe2OdHue7US3lnEy-qwuqw2MGls1toYj9A3w0YhYitWVcg" name="csrf-token"/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1179606-29">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-1179606-29');
#   </script>
#   <script>
#    window.fbAsyncInit = function() {
#       FB.init({
#         appId            : '483774921971842',
#         autoLogAppEvents : true,
#         xfbml            : true,
#         version          : 'v6.0'
#       });
#     };
#   </script>
#   <script async="" defer="" src="https://connect.facebook.net/en_US/sdk.js">
#   </script>
#   <meta content="483774921971842" property="fb:app_id"/>
#   <link href="https://www.passiton.com/inspirational-quotes.atom" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="no-transition quotes_index">
#   <header>
#    <nav class="navbar navbar-default bootsnav background-transparent header-dark white-link navbar-fixed-top navbar-expand-lg nav-box-width">
#     <div class="container-fluid nav-header-container">
#      <div class="col-auto pl-0">
#       <a class="logo" href="/" title="Pass It On®">
#        <img alt="Pass It On" class="logo-dark" data-rjs="/assets/site/logo@2x-9d23e0957dd55796d7703439c50bc254ab2499f99c40f36603e12ede1b4171f0.png" src="/assets/site/logo-1be5a8827b761a60c300142c5126fc96abc085520555801120a17feb4fa49495.png"/>
#        <img alt="Pass It On" class="logo-light default" data-rjs="/assets/site/logo-white@2x-52919a88e1cc19ef3bf0977d9618e8428645f46fac094c1925aa0898381647f3.png" src="/assets/site/logo-white-c2e757031d75c9b2cbfe36fb361278a725b48f39566e2c4032ac0f77e5c0b7ab.png"/>
#       </a>
#      </div>
#      <div class="col accordion-menu pr-0 pr-md-3">
#       <button class="navbar-toggler collapsed" data-target="#navbar-collapse-toggle-1" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <div class="navbar-collapse collapse justify-content-end" id="navbar-collapse-toggle-1">
#        <ul class="nav navbar-nav navbar-left no-margin alt-font text-normal" data-in="fadeIn" data-out="fadeOut" id="accordion">
#         <li>
#          <a href="/inspirational-quotes">
#           Quotes
#          </a>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/inspirational-stories-tv-spots">
#           Videos
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/inspirational-stories-tv-spots">
#             Official Pass It On® Videos
#            </a>
#           </li>
#           <li>
#            <a href="/artcenter-psas">
#             ArtCenter College of Design PSAs
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/inspirational-sayings-billboards">
#           Billboards
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/inspirational-sayings-billboards">
#             Official Billboards
#            </a>
#           </li>
#           <li>
#            <a href="/is-in-you">
#             Is In You® Billboards
#            </a>
#           </li>
#           <li>
#            <a href="/your-billboards">
#             Create Your Own Billboard
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a href="/positive-good-news-columns">
#           Newspapers
#          </a>
#         </li>
#         <li>
#          <a href="/radio">
#           Radio
#          </a>
#         </li>
#         <li>
#          <a href="/passiton-blog">
#           Blog
#          </a>
#         </li>
#         <li>
#          <a href="/poster-requests/new">
#           Schools
#          </a>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="#">
#           <i aria-hidden="true" class="fas fa-globe d-none d-lg-inline text-normal">
#           </i>
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="https://www.pasala.org/" target="_blank">
#             Spanish | Español
#            </a>
#           </li>
#           <li>
#            <a href="https://www.umavidamelhor.org/" target="_blank">
#             Portuguese | Português
#            </a>
#           </li>
#           <li>
#            <a href="https://www.values.cn.com/" target="_blank">
#             Chinese | 中文
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-auto pr-0">
#       <div class="header-searchbar">
#        <a aria-label="search form" class="header-search-form" href="#search-header">
#         <i class="fas fa-search search-button">
#         </i>
#        </a>
#        <form action="/search" class="mfp-hide search-form-result" id="search-header" method="post" name="search-header">
#         <div class="search-form position-relative">
#          <button aria-label="Search" class="fas fa-search close-search search-button" type="submit">
#          </button>
#          <input autocomplete="off" class="search-input" name="q" placeholder="Search passiton.com..." type="text"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <section class="parallax padding-six-all bg-black" data-stellar-background-ratio="0.2" style="background-image:url('/assets/backgrounds/flowers-7e362d59b798265063c210d16ea800b6fb4c3b13e462fbfe195df7c70c9811ce.jpg');">
#    <div class="container">
#     <div class="row justify-content-center">
#      <div class="col-12 col-lg-10 text-center">
#       <div class="shadow bg-extra-dark-gray padding-two-all border-radius-6 width-70 lg-width-80 sm-width-100 mx-auto lg-padding-30px-all sm-padding-15px-all sm-margin-40px-top">
#        <h6 class="font-weight-300 text-white-2 margin-20px-bottom sm-margin-15px-bottom">
#         Get our FREE daily quote emails!
#        </h6>
#        <p class="text-medium text-white-2 width-70 mx-auto margin-40px-bottom sm-width-100 sm-margin-15px-bottom">
#         Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe.
#        </p>
#        <form accept-charset="UTF-8" action="/users" class="simple_form search-box3 margin-10px-bottom" id="new_user" method="post" novalidate="novalidate">
#         <input autocomplete="off" name="authenticity_token" type="hidden" value="ydK-ZOMYPL95T6IVzY1AS19RVawBSsKGpQZ-IZI3671QeYKpEf7XXTApA_P_ASA5fXrA9wVQPJLbhjKUu4Ztdg"/>
#         <script src="https://www.recaptcha.net/recaptcha/api.js?render=6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6">
#         </script>
#         <script>
#          // Define function so that we can call it again later if we need to reset it
#           // This executes reCAPTCHA and then calls our callback.
#           function executeRecaptchaForSignup() {
#             grecaptcha.ready(function() {
#               grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) {
#                 setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token)
#               });
#             });
#           };
#           // Invoke immediately
#           executeRecaptchaForSignup()
#
#           // Async variant so you can await this function from another async function (no need for
#           // an explicit callback function then!)
#           // Returns a Promise that resolves with the response token.
#           async function executeRecaptchaForSignupAsync() {
#             return new Promise((resolve, reject) => {
#              grecaptcha.ready(async function() {
#                 resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}))
#               });
#             })
#           };
#
#                     var setInputWithRecaptchaResponseTokenForSignup = function(id, token) {
#             var element = document.getElementById(id);
#             element.value = token;
#           }
#         </script>
#         <input class="g-recaptcha g-recaptcha-response" data-sitekey="6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6" id="g-recaptcha-response-data-signup" name="g-recaptcha-response-data[signup]" type="hidden"/>
#         <div class="input-group add-on width-75 mx-auto sm-width-100">
#          <input class="string email optional form-control text-white" id="user_email" label="false" name="user[email]" placeholder="you@youremail.com" type="text" value=""/>
#          <div class="input-group-append">
#           <button aria-label="Submit" class="btn btn-default" type="submit">
#            <i class="ti-arrow-right text-small m-0">
#            </i>
#           </button>
#          </div>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section class="half-section bg-extra-dark-gray half-section">
#    <div class="container">
#     <div class="row m-0">
#      <div class="col-12 d-flex flex-column justify-content-center text-center wow fadeIn" data-wow-delay="0.2s">
#       <h5 class="text-white alt-font font-weight-400 letter-spacing-1 margin-10px-bottom">
#        INSPIRATIONAL QUOTES
#       </h5>
#       <span class="text-white-2 opacity8 alt-font mb-0 padding-20px-bottom">
#        Find the perfect quote... and Pass It On®
#       </span>
#       <form action="/inspirational-quotes" class="search-box2 margin-30px-bottom" method="get">
#        <div class="input-group add-on width-75 mx-auto sm-width-100">
#         <input class="form-control text-white-2" name="q" placeholder="Search our inspiring quotes..." type="text" value=""/>
#         <div class="input-group-append">
#          <button aria-label="Search" class="btn btn-default" type="submit">
#           <i class="ti-search text-small m-0">
#           </i>
#          </button>
#         </div>
#        </div>
#       </form>
#      </div>
#     </div>
#     <div class="row m-0">
#      <div class="col-8 d-flex flex-column justify-content-top text-center">
#       <div class="row" id="all_quotes">
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7928-the-world-is-incomprehensibly-beautiful-an">
#          <img alt="The world is incomprehensibly beautiful—an endless prospect of magic and wonder. #&lt;Author:0x00007fd3660a4100&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7928/medium/20221104_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7928-the-world-is-incomprehensibly-beautiful-an">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7511-to-be-whole-to-be-complete-wildness-reminds">
#          <img alt="To be whole. To be complete. Wildness reminds us what it means to be human, what we are connected to rather than what we are separate from. #&lt;Author:0x00007fd3660f7468&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7511/medium/20221103_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7511-to-be-whole-to-be-complete-wildness-reminds">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8224-of-all-the-paths-you-take-in-life-make-sure-a">
#          <img alt="Of all the paths you take in life, make sure a few of them are dirt. #&lt;Author:0x00007fd3660e5538&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8224/medium/20221102_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8224-of-all-the-paths-you-take-in-life-make-sure-a">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8131-nature-brings-solace-in-all-troubles">
#          <img alt="Nature brings solace in all troubles. #&lt;Author:0x00007fd3660ce7c0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8131/medium/20221101_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8131-nature-brings-solace-in-all-troubles">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8226-an-early-morning-walk-is-a-blessing-for-the">
#          <img alt="An early morning walk is a blessing for the whole day. #&lt;Author:0x00007fd366117d08&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8226/medium/20221031_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8226-an-early-morning-walk-is-a-blessing-for-the">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/4080-to-forgive-is-to-set-a-prisoner-free-and">
#          <img alt="To forgive is to set a prisoner free and discover that the prisoner was you. #&lt;Author:0x00007fd366105630&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4080/medium/20221028_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/4080-to-forgive-is-to-set-a-prisoner-free-and">
#           FORGIVENESS
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/4448-without-forgiveness-theres-no-future">
#          <img alt="Without forgiveness, there's no future. #&lt;Author:0x00007fd3661d5240&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4448/medium/20221027_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/4448-without-forgiveness-theres-no-future">
#           FORGIVENESS
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/3794-you-have-many-choices-you-can-choose">
#          <img alt="You have many choices. You can choose forgiveness over revenge, joy over despair. You can choose action over apathy. #&lt;Author:0x00007fd3661577f0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/3794/medium/20221026_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/3794-you-have-many-choices-you-can-choose">
#           FORGIVENESS
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8365-mistakes-are-always-forgivable-if-one-has-the">
#          <img alt="Mistakes are always forgivable, if one has the courage to admit them. #&lt;Author:0x00007fd36626dcc0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8365/medium/20221025_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8365-mistakes-are-always-forgivable-if-one-has-the">
#           FORGIVENESS
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8205-true-forgiveness-is-when-you-can-say-thank-you">
#          <img alt="True forgiveness is when you can say ‘Thank you for that experience’. #&lt;Author:0x00007fd366245450&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8205/medium/20221024_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8205-true-forgiveness-is-when-you-can-say-thank-you">
#           FORGIVENESS
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8152-dont-ever-forget-that-youre-a-citizen-of-this">
#          <img alt="Don't ever forget that you're a citizen of this world, and there are things you can do to lift the human spirit, things that are easy, things that are free, things that you can do every day: civility, respect, kindness, character. #&lt;Author:0x00007fd3662cc950&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8152/medium/20221021_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8152-dont-ever-forget-that-youre-a-citizen-of-this">
#           CHARACTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7410-you-may-encounter-many-defeats-but-you-must">
#          <img alt="You may encounter many defeats, but you must not be defeated. In fact, it may be necessary to encounter the defeats, so you can know who you are, what you can rise from, how you can still come out of it. #&lt;Author:0x00007fd3662a4888&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7410/medium/20221020_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7410-you-may-encounter-many-defeats-but-you-must">
#           CHARACTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/4393-people-grow-through-experience-if-they-meet">
#          <img alt="People grow through experience if they meet life honestly and courageously. This is how character is built. #&lt;Author:0x00007fd36627f8f8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4393/medium/20221019_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/4393-people-grow-through-experience-if-they-meet">
#           CHARACTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7367-our-character-is-what-we-do-when-we-think-no">
#          <img alt="Our character is what we do when we think no one is looking. #&lt;Author:0x00007fd36631ea70&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7367/medium/20221018_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7367-our-character-is-what-we-do-when-we-think-no">
#           CHARACTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/3819-character-consists-of-what-you-do-on-the-third">
#          <img alt="Character consists of what you do on the third and fourth tries. #&lt;Author:0x00007fd3662dead8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/3819/medium/20221017_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/3819-character-consists-of-what-you-do-on-the-third">
#           CHARACTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7461-laugh-my-friend-for-laughter-ignites-a-fire">
#          <img alt="Laugh my friend, for laughter ignites a fire within the pit of your belly and awakens your being. #&lt;Author:0x00007fd36636f588&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7461/medium/20221014_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7461-laugh-my-friend-for-laughter-ignites-a-fire">
#           LAUGHTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7462-the-most-wasted-of-all-days-is-one-without">
#          <img alt="The most wasted of all days is one without laughter. #&lt;Author:0x00007fd36634e0e0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7462/medium/20221013_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7462-the-most-wasted-of-all-days-is-one-without">
#           LAUGHTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8350-in-all-of-living-have-much-joy-and-laughter">
#          <img alt="In all of living have much joy and laughter. Life is to be enjoyed not just endured. #&lt;Author:0x00007fd3663b7428&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8350/medium/20221012_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8350-in-all-of-living-have-much-joy-and-laughter">
#           LAUGHTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6344-may-your-walls-know-joy-may-every-room-hold">
#          <img alt="May your walls know joy, may every room hold laughter, and every window open to great possibility. #&lt;Author:0x00007fd366395e68&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6344/medium/20221011_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6344-may-your-walls-know-joy-may-every-room-hold">
#           LAUGHTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/3137-laughter-is-the-shortest-distance-between-two">
#          <img alt="Laughter is the shortest distance between two people. #&lt;Author:0x00007fd366405268&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/3137/medium/20221010_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/3137-laughter-is-the-shortest-distance-between-two">
#           LAUGHTER
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8364-listen-carefully-the-answers-to-our-deepest">
#          <img alt="Listen carefully. The answers to our deepest questions are often whispered. #&lt;Author:0x00007fd3663e69d0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8364/medium/20221007_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8364-listen-carefully-the-answers-to-our-deepest">
#           LISTENING
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8363-with-the-gift-of-listening-comes-the-gift-of">
#          <img alt="With the gift of listening comes the gift of healing. #&lt;Author:0x00007fd3663ce588&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8363/medium/20221006_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8363-with-the-gift-of-listening-comes-the-gift-of">
#           LISTENING
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8362-listening-is-about-being-present-not-just">
#          <img alt="Listening is about being present, not just about being quiet. #&lt;Author:0x00007fd36642eaf0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8362/medium/20221005_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8362-listening-is-about-being-present-not-just">
#           LISTENING
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7323-too-often-we-underestimate-the-power-of-a">
#          <img alt="Too often we underestimate the power of a touch, a smile, a kind word... all of which have the potential to turn a life around. #&lt;Author:0x00007fd36640fc90&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7323/medium/20221004_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7323-too-often-we-underestimate-the-power-of-a">
#           LISTENING
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7608-listening-is-where-love-begins-listening-to">
#          <img alt="Listening is where love begins: listening to ourselves and then to our neighbors. #&lt;Author:0x00007fd366464ec0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7608/medium/20221003_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7608-listening-is-where-love-begins-listening-to">
#           LISTENING
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7921-be-humble-in-your-confidence-yet-courageous-in">
#          <img alt="Be humble in your confidence yet courageous in your character. #&lt;Author:0x00007fd36644e710&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7921/medium/20220930_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7921-be-humble-in-your-confidence-yet-courageous-in">
#           HUMILITY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7920-humility-is-not-thinking-less-of-yourself-its">
#          <img alt="Humility is not thinking less of yourself, it's thinking of yourself less. #&lt;Author:0x00007fd366497f00&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7920/medium/20220929_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7920-humility-is-not-thinking-less-of-yourself-its">
#           HUMILITY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7039-true-humility-is-being-able-to-accept">
#          <img alt="True humility is being able to accept criticisms as graciously as we accept compliments. #&lt;Author:0x00007fd3664862a0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7039/medium/20220928_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7039-true-humility-is-being-able-to-accept">
#           HUMILITY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7922-pride-is-concerned-with-who-is-right-humility">
#          <img alt="Pride is concerned with who is right. Humility is concerned with what is right. #&lt;Author:0x00007fd366474168&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7922/medium/20220927_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7922-pride-is-concerned-with-who-is-right-humility">
#           HUMILITY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8094-humility-is-the-solid-foundation-of-all-virtues">
#          <img alt="Humility is the solid foundation of all virtues. #&lt;Author:0x00007fd3664bd5c0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8094/medium/20220926_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8094-humility-is-the-solid-foundation-of-all-virtues">
#           HUMILITY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8361-acceptance-doesnt-mean-resignation-it-means">
#          <img alt="Acceptance doesn't mean resignation; it means understanding that something is what it is and that there's got to be a way through it. #&lt;Author:0x00007fd3664a6050&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8361/medium/20220923_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8361-acceptance-doesnt-mean-resignation-it-means">
#           ACCEPTANCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7803-i-think-tolerance-and-acceptance-and-love-is">
#          <img alt="I think tolerance and acceptance and love is something that feeds every community. #&lt;Author:0x00007fd3664efe08&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7803/medium/20220922_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7803-i-think-tolerance-and-acceptance-and-love-is">
#           ACCEPTANCE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8254-acceptance-is-simply-love-in-practice-when-you">
#          <img alt="Acceptance is simply love in practice. When you love, you accept, when you lack love, you judge. #&lt;Author:0x00007fd3664ddb90&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8254/medium/20220921_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8254-acceptance-is-simply-love-in-practice-when-you">
#           ACCEPTANCE
#          </a>
#         </h5>
#        </div>
#       </div>
#      </div>
#      <div class="col-4 d-flex flex-column text-center">
#       <div class="row" id="all_quotes">
#        <span class="text-white text-left alt-font font-weight-400 letter-spacing-1 margin-20px-bottom" style="font-size:  20px;">
#         We publish our quotes and other inspirational stories on Facebook. Please 'like' our page to get daily inspiration.
#        </span>
#        <div class="fb-page" data-adapt-container-width="true" data-height="3000" data-hide-cover="false" data-href="https://www.facebook.com/valuescom" data-show-facepile="true" data-small-header="true" data-tabs="timeline" data-width="">
#         <blockquote cite="https://www.facebook.com/valuescom" class="fb-xfbml-parse-ignore">
#          <a href="https://www.facebook.com/valuescom">
#           Foundation for A Better Life
#          </a>
#         </blockquote>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-12 text-center">
#       <nav aria-label="pager" class="pagination" role="navigation">
#        <span class="page current">
#         1
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=2" rel="next">
#          2
#         </a>
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=3">
#          3
#         </a>
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=4">
#          4
#         </a>
#        </span>
#        <span class="page">
#         <a href="/inspirational-quotes?page=5">
#          5
#         </a>
#        </span>
#        <span class="page gap">
#         …
#        </span>
#        <span class="next">
#         <a href="/inspirational-quotes?page=2" rel="next">
#          Next ›
#         </a>
#        </span>
#        <span class="last">
#         <a href="/inspirational-quotes?page=76">
#          Last »
#         </a>
#        </span>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </section>
#   <footer class="footer-classic-dark bg-extra-dark-gray padding-five-bottom sm-padding-30px-bottom">
#    <div class="bg-dark-footer padding-50px-tb sm-padding-30px-tb">
#     <div class="container">
#      <div class="row align-items-center">
#       <div class="col-lg-4 col-md-4 sm-text-center lg-text-left alt-font sm-margin-15px-bottom">
#        <a href="/">
#         <img alt="PassItOn.com The Foundation for a Better Life" class="footer_logo" data-rjs="/assets/site/passiton_fbl_logo-130047b5350655ed0505fbb6bf8d137784664a78481a2ed020a9b5b73c7ec3d9.png" src="/assets/site/passiton_fbl_logo-130047b5350655ed0505fbb6bf8d137784664a78481a2ed020a9b5b73c7ec3d9.png" style="max-width: 200px;"/>
#        </a>
#       </div>
#       <div class="col-lg-4 col-md-4 text-center sm-margin-10px-bottom">
#       </div>
#       <div class="col-lg-4 col-md-4 text-center">
#        <span class="alt-font margin-20px-right text-light-gray">
#         Follow us on social
#        </span>
#        <div class="social-icon-style-8 d-inline-block vertical-align-middle">
#         <ul class="small-icon mb-0">
#          <li>
#           <a aria-label="facebook" class="facebook text-white-2" href="https://www.facebook.com/valuescom" target="_blank">
#            <i aria-hidden="true" class="fab fa-facebook-f">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="twitter" class="twitter text-white-2" href="https://twitter.com/passiton_values" target="_blank">
#            <i class="fab fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="instagram" class="instagram text-white-2" href="https://www.instagram.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-instagram no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="pinterest" class="pinterest text-white-2" href="https://www.pinterest.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-pinterest no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="youtube" class="youtube text-white-2" href="https://www.youtube.com/c/passiton_values" target="_blank">
#            <i aria-hidden="true" class="fab fa-youtube no-margin-right">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-widget-area padding-five-top padding-30px-bottom sm-padding-30px-top">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         About Us
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/who-we-are">
#           About The Foundation for a Better Life
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/faqs">
#           FAQs
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/foundation-recognition">
#           Foundation Recognition
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/contact-us">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         Be Inspired
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/teaching-values">
#           Teaching Values
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-quotes">
#           Inspirational Quotations
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-stories-tv-spots">
#           Pass It On® Videos
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/artcenter-psas">
#           ArtCenter College of Design PSAs
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/positive-good-news-columns">
#           Free Newspaper Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/your-everyday-heroes">
#           Who's Your Hero Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-sayings-billboards">
#           Official Billboard Campaign
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/your-billboards">
#           Create Your Own Billboard
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/radio">
#           Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/passiton-blog">
#           Pass It On® Blog
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-audio-stories">
#           Podcasts
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-ecards">
#           Send an Ecard
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Schools
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/poster-requests/new">
#           Free Posters &amp; DVD for Schools
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-downloads">
#           Downloads
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Media Companies
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/for-media-companies">
#           For Media Companies
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Broadcast Quality PSA Downloads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Pass It On Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Live Reads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Out of Home Materials
#          </a>
#         </li>
#        </ul>
#        <div class="row sm-margin-30px-top">
#         <div class="col-lg-4">
#          <a href="/">
#           <img alt="values.com logo" src="/assets/site/values_logo-d2f298a8d307ac7a45b2651f13796052ecfd37d37d73b102f7c910ee6e2eabc2.png" style="max-width: 70px;"/>
#          </a>
#         </div>
#         <div class="col-lg-7">
#          <p class="text-light-gray text-small padding-10px-top">
#           VALUES.COM
#           <small>
#            ®
#           </small>
#           is now PassItOn.com
#           <small>
#            ®
#           </small>
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="footer-bottom border-top border-color-medium-dark-gray padding-30px-top">
#      <div class="row">
#       <div class="col-lg-6 col-md-6 text-small text-light-gray text-md-left text-center">
#        ©2000-2022 The Foundation for a Better Life.
#       </div>
#       <div class="col-lg-6 col-md-6 text-small text-light-gray text-md-right text-center">
#        <a class="text-light-gray" href="/privacy-policy">
#         Privacy Policy
#        </a>
#        |
#        <a class="text-light-gray" href="/terms-of-use">
#         Terms of Use
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <a class="scroll-top-arrow" href="javascript:void(0);">
#    <i class="ti-arrow-up">
#    </i>
#   </a>
#   <script data-turbo-track="reload" src="/assets/application-f19ee8c9a29f15116a04e84d403d88b7866b3228217ffb0c4fe2cc3ce6656779.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-jcrop/0.9.15/js/jquery.Jcrop.min.js">
#   </script>
#   <div class="zoom-anim-dialog mfp-hide col-xl-6 col-lg-6 col-md-7 col-11 mx-auto bg-white text-center modal-popup-main padding-50px-all" id="please_like_us_on_facebook">
#    <span class="text-extra-dark-gray text-uppercase alt-font text-extra-large font-weight-600 margin-15px-bottom d-block">
#     LIKE US ON FACEBOOK FOR A DAILY DOSE OF POSITIVITY
#    </span>
#    <iframe allow="autoplay; clipboard-write; encrypted-media; picture-in-picture; web-share" allowfullscreen="true" frameborder="0" height="45" scrolling="no" src="https://www.facebook.com/plugins/like.php?href=https%3A%2F%2Fwww.facebook.com%2Fvaluescom&amp;width=450&amp;layout=standard&amp;action=like&amp;size=large&amp;share=true&amp;height=45&amp;appId" style="border:none;overflow:hidden;font-size:1.4rem;" width="450">
#    </iframe>
#    <p class="padding-20px-all font-weight-600">
#     Click the like button above to access our facebook page, then ‘like us’ to get a dose of positivity in your feed.
#    </p>
#    <a class="text-small alt-font popup-modal-dismiss text-decoration-underline" href="#">
#     No thanks
#    </a>
#   </div>
#  </body>
# </html>
